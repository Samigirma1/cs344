# %%
from keras.datasets import imdb
from keras import models, layers, optimizers

import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)
# Our vectorized labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# create a validation set
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
# suggested model
# suggestedModel = models.Sequential()
# suggestedModel.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
# suggestedModel.add(layers.Dense(16, activation='relu'))
# suggestedModel.add(layers.Dense(1, activation='sigmoid'))
# suggestedModel.compile(optimzer = optimizers.RMSprop(lr = 0.001), loss = "binary_crossentropy", metrics = ["accuracy"])
#
# history = suggestedModel.fit(partial_x_train,
#                     partial_y_train,
#                     epochs=20,
#                     batch_size=512,
#                     validation_data=(x_val, y_val))

model = models.Sequential()
model.add(layers.Dense(16, activation='tanh', input_shape=(10000,)))
model.add(layers.Dense(16, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 1s 42us/step - loss: 0.4259 - accuracy: 0.8370
# Epoch 2/4
# 25000/25000 [==============================] - 1s 41us/step - loss: 0.2361 - accuracy: 0.9158
# Epoch 3/4
# 25000/25000 [==============================] - 1s 41us/step - loss: 0.1796 - accuracy: 0.9350
# Epoch 4/4
# ...
# 25000/25000 [==============================] - 2s 87us/step

# %%
results
# Out:
# [0.3170050592374802, 0.8786399960517883]

# %%
# suggested model
# suggestedModel = models.Sequential()
# suggestedModel.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
# suggestedModel.add(layers.Dense(16, activation='relu'))
# suggestedModel.add(layers.Dense(1, activation='sigmoid'))
# suggestedModel.compile(optimzer = optimizers.RMSprop(lr = 0.001), loss = "binary_crossentropy", metrics = ["accuracy"])
#
# history = suggestedModel.fit(partial_x_train,
#                     partial_y_train,
#                     epochs=20,
#                     batch_size=512,
#                     validation_data=(x_val, y_val))

modelMore = models.Sequential()
modelMore.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
modelMore.add(layers.Dense(16, activation='relu'))
modelMore.add(layers.Dense(16, activation='relu'))
modelMore.add(layers.Dense(1, activation='sigmoid'))

modelMore.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

modelMore.fit(x_train, y_train, epochs=4, batch_size=512)
resultsMore = modelMore.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 1s 50us/step - loss: 0.4798 - accuracy: 0.7995
# Epoch 2/4
# 25000/25000 [==============================] - 1s 54us/step - loss: 0.2568 - accuracy: 0.9096
# Epoch 3/4
# 25000/25000 [==============================] - 1s 58us/step - loss: 0.1944 - accuracy: 0.9301
# Epoch 4/4
# ...
# 25000/25000 [==============================] - 2s 81us/step

# %%
resultsMore
# Out:
# [0.31340735652923585, 0.8789600133895874]

# %%
# suggested model
# suggestedModel = models.Sequential()
# suggestedModel.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
# suggestedModel.add(layers.Dense(16, activation='relu'))
# suggestedModel.add(layers.Dense(1, activation='sigmoid'))
# suggestedModel.compile(optimzer = optimizers.RMSprop(lr = 0.001), loss = "binary_crossentropy", metrics = ["accuracy"])
#
# history = suggestedModel.fit(partial_x_train,
#                     partial_y_train,
#                     epochs=20,
#                     batch_size=512,
#                     validation_data=(x_val, y_val))

modelLess = models.Sequential()
modelLess.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
modelLess.add(layers.Dense(16, activation='relu'))
modelLess.add(layers.Dense(1, activation='sigmoid'))

modelLess.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

modelLess.fit(x_train, y_train, epochs=4, batch_size=512)
resultsLess = modelLess.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 1s 52us/step - loss: 0.4684 - accuracy: 0.8222
# Epoch 2/4
# 25000/25000 [==============================] - 1s 45us/step - loss: 0.2677 - accuracy: 0.9093
# Epoch 3/4
# 25000/25000 [==============================] - 1s 48us/step - loss: 0.2055 - accuracy: 0.9276
# Epoch 4/4
# ...
# 25000/25000 [==============================] - 2s 85us/step

# %%
resultsLess
# Out:
# [0.2949476030921936, 0.8825600147247314]

# %%
# suggested model
# suggestedModel = models.Sequential()
# suggestedModel.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
# suggestedModel.add(layers.Dense(16, activation='relu'))
# suggestedModel.add(layers.Dense(1, activation='sigmoid'))
# suggestedModel.compile(optimzer = optimizers.RMSprop(lr = 0.001), loss = "binary_crossentropy", metrics = ["accuracy"])
#
# history = suggestedModel.fit(partial_x_train,
#                     partial_y_train,
#                     epochs=20,
#                     batch_size=512,
#                     validation_data=(x_val, y_val))

modelMoreUnits = models.Sequential()
modelMoreUnits.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
modelMoreUnits.add(layers.Dense(64, activation='relu'))
modelMoreUnits.add(layers.Dense(1, activation='sigmoid'))

modelMoreUnits.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

modelMoreUnits.fit(x_train, y_train, epochs=4, batch_size=512)
resultsLess = modelMoreUnits.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 1s 55us/step - loss: 0.4243 - accuracy: 0.8113
# Epoch 2/4
# 25000/25000 [==============================] - 1s 53us/step - loss: 0.2417 - accuracy: 0.9057
# Epoch 3/4
# 25000/25000 [==============================] - 1s 50us/step - loss: 0.1845 - accuracy: 0.9307
# Epoch 4/4
# ...
# 25000/25000 [==============================] - 2s 65us/step

# %%
resultsLess
# Out:
# [0.30514850316524506, 0.8800399899482727]
